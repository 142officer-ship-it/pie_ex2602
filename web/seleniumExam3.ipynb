# %%
'''
[Selenium 활용 예제]

연습 사이트
https://quotes.toscrape.com
'''

from selenium import webdriver
from selenium.webdriver.common.by import By

# ================================================
# 0) 브라우저 실행 + 페이지 접속
# ================================================
driver = webdriver.Chrome()
driver.get("https://quotes.toscrape.com")


# ================================================
# 1) 한 페이지에서 여러 명언 수집하기
# ================================================

# 수집한 데이터를 저장할 리스트
results = []

print("====1페이지 수집 시작====")

quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

for block in quote_blocks:
    # 각 블록 안에서 필요한 데이터 찾기
    quote_text = block.find_element(By.CLASS_NAME, "text").text
    author = block.find_element(By.CLASS_NAME, "author").text

# 태그는 여러 개일 수 있으므로 find_elements 사용
    tag_elements = block.find_elements(By.CLASS_NAME, "tag")

    tags = [t.text for t in tag_elements]
    # 리스트 컴프리핸션을 사용하여 각 tag 요소의 텍스트만 추출
    #   - (컴프리핸션: 반복문을 이용해 새로운 컬렉션을 만드는 축약 문법)
    #   - [표현식 for 변수 in 반복가능객체]
    # 최종적으로 tags는 문자열 리스트 형태가 됨
    # 아래 형태와 똑같다.
    # tags = []
    # for i in tag_elements:
    #     tags.append(t.text)

    results.append({
        "page": 1,
        "quote": quote_text,
        "author": author,
        "tags": tags
    })

    print(author, "-", quote_text)

print("현재까지 수집 갯수 :", len(results))   

driver.quit()
# Out:
# ====1페이지 수집 시작====
# Albert Einstein - “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# J.K. Rowling - “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# Albert Einstein - “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# Jane Austen - “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# Marilyn Monroe - “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# Albert Einstein - “Try not to become a man of success. Rather become a man of value.”
# André Gide - “It is better to be hated for what you are than to be loved for what you are not.”
# Thomas A. Edison - “I have not failed. I've just found 10,000 ways that won't work.”
# Eleanor Roosevelt - “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# Steve Martin - “A day without sunshine is like, you know, night.”
# 현재까지 수집 갯수 : 10

# %%
# ================================================
# 2) 다음 페이지 이동 + 반복 수집
# ================================================

# 최대 몇 페이지까지 수집할지 제한하는 상수
# 무한 크롤링을 방지하기 위한 안전 장치
MAX_PAGES = 3

# 현재 페이지 번호를 추적하기 위한 변수
current_page = 1

while current_page < MAX_PAGES:
    # Next 버튼 찾기
    # "li.next a"는 class="next"를 가진 li안의 a태그 의미
    next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")

    # Next 버튼이 없으면 종료
    if not next_buttons:
        print("다음 페이지가 없어 종료합니다.")
        break
    
    # 다음 페이지 이동
    next_buttons[0].click()

    # 페이지 번호 1 증가
    current_page += 1

    # 현재 수집 중인 페이지 번호 출력
    print(f"\n==== {current_page}페이지 수집 중 ====")

    # 새 페이지에서 다시 quote 블록 수집
    quote_blocks = driver.find_elements(By.CLASS_NAME, "quote")

    for block in quote_blocks:
        quote_text = block.find_element(By.CLASS_NAME, "text").text
        author = block.find_element(By.CLASS_NAME, "author").text
        tag_elements = block.find_elements(By.CLASS_NAME, "tag").text
        tags = [t.text for t in tag_elements]

        results.append({
        "page": 1,
        "quote": quote_text,
        "author": author,
        "tags": tags
    })

print("\n최종 수집 개수 :", len(results))
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[11], line 15
#      10 current_page = 1
#      12 while current_page < MAX_PAGES:
#      13     # Next 버튼 찾기
#      14     # "li.next a"는 class="next"를 가진 li안의 a태그 의미
# ---> 15     next_buttons = driver.find_elements(By.CSS_SELECTOR, "li.next a")
#      17     # Next 버튼이 없으면 종료
#      18     if not next_buttons:
#
# File c:\Users\202\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:847, in WebDriver.find_elements(self, by, value)
#     843     return self.execute_script(find_element_js, by.to_dict())
#     845 # Return empty list if driver returns null
#     846 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 847 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File c:\Users\202\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# File c:\Users\202\AppData\Local\Programs\Python\Python314\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# Symbols not available. Dumping unresolved backtrace:
# 	0x7ff6aa22aa55
# 	0x7ff6a9f88630
# 	0x7ff6a9d1d546
# 	0x7ff6a9d68113
# 	0x7ff6a9da18e2
# 	0x7ff6a9d9bb11
# 	0x7ff6a9d9adc3
# 	0x7ff6a9ce6505
# 	0x7ff6aa257810
# 	0x7ff6aa251afd
# 	0x7ff6aa272c1a
# 	0x7ff6a9fa3345
# 	0x7ff6a9fab81c
# 	0x7ff6a9ce536a
# 	0x7ff6aa3b2b08
# 	0x7ffc71547374
# 	0x7ffc71afcc91
